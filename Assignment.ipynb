# %%
#1
# string function
text = 'aiml'


print("\nUpper String:")
print(text.upper())


print("\nLower String:")
print(text.lower())


print("\nConverted String:")
print(text.title())


print("\nOriginal String")
print(text)

print("\nConverted String")
print(text.swapcase())

print("\nCount String")
print(text.count('i'))

print("\nConverted String")
print(text.capitalize())
# Out:
# Upper String:
# AIML
#
# Lower String:
# aiml
#
# Converted String:
# Aiml
#
# Original String
# aiml
#
# Converted String
# AIML
#
# Count String
# 1
#
# Converted String
# Aiml

# %%
#2
List = ['Mathematics', 'chemistry', 1997, 2000]
List.append(20544)
print(List)



List.insert(2,10087)    
print(List)

List1 = [1, 2, 3]
List2 = [2, 3, 4, 5]

List1.extend(List2)
print(List1)

List2.extend(List1)
print(List2)

List = [1, 2, 3, 4, 5]
print(sum(List))

print(List.count(1))
print(len(List))

print(List.index(2))

List.remove(3)
print(List)
# Out:
# ['Mathematics', 'chemistry', 1997, 2000, 20544]
# ['Mathematics', 'chemistry', 10087, 1997, 2000, 20544]
# [1, 2, 3, 2, 3, 4, 5]
# [2, 3, 4, 5, 1, 2, 3, 2, 3, 4, 5]
# 15
# 1
# 5
# 1
# [1, 2, 4, 5]

# %%
#3
Tuple = (0, 1, 2, 3, 2, 3, 1, 3, 2)
Tuple2 = ('python', 'geek', 'python', 
          'for', 'java', 'python')
  
# count the appearance of 3
x = Tuple.count(3)
print('Count of 3 in Tuple1 is:', x)

y = Tuple2.count('geek')
print('Count of 3 in Tuple1 is:', y)

res = Tuple.index(3)
print('First occurrence of 3 is', res)
# Out:
# Count of 3 in Tuple1 is: 3
# Count of 3 in Tuple1 is: 1
# First occurrence of 3 is 3

# %%
#4
text = {1: "reeks", 2: "for"}
 
text.clear()
print('text =', text)

dict1 = {10: 'a', 20: [1, 2, 3], 30: 'c'}
print("Given Dictionary:", dict1)
 

dict2 = dict1.copy()
print("New copy:", dict2)

dict2[10] = 10
dict2[20][2] = '45' 
 
print("Updated copy:", dict2)

x = ('a', 'b', 'c')
print(dict.fromkeys(x, None))

my_dict={"name":"siefert",101:"english"}
print(my_dict["name"])
print(my_dict.keys())
print(my_dict.keys())
print(my_dict.values())
print(my_dict.get("name"))
print(my_dict.get(101))
# Out:
# text = {}
# Given Dictionary: {10: 'a', 20: [1, 2, 3], 30: 'c'}
# New copy: {10: 'a', 20: [1, 2, 3], 30: 'c'}
# Updated copy: {10: 10, 20: [1, 2, '45'], 30: 'c'}
# {'a': None, 'b': None, 'c': None}
# siefert
# dict_keys(['name', 101])
# dict_keys(['name', 101])
# dict_values(['siefert', 'english'])
# siefert
# english

# %%
#5
s = {'a', 'e', 'k', 'f'}
 

s.add('f')
print('Set after updating:', s)
 

s.discard('g')
print('\nSet after updating:', s)
 

s.remove('e')
print('\nSet after updating:', s)
 

print('\nPopped element', s.pop())
print('Set after updating:', s)
 
s.clear()
print('\nSet after updating:', s)
# Out:
# Set after updating: {'e', 'k', 'f', 'a'}
#
# Set after updating: {'e', 'k', 'f', 'a'}
#
# Set after updating: {'k', 'f', 'a'}
#
# Popped element k
# Set after updating: {'f', 'a'}
#
# Set after updating: set()

# %%
#6
m=547
print(bin(m))

print(hex(m))

print(oct(m))
# Out:
# 0b1000100011
# 0x223
# 0o1043

# %%
#7
x = 2
y = 3

z = x + y
print(z)

z = x - y
print(z)

z = x * y
print(z)

z = x / y
print(z)
# Out:
# 5
# -1
# 6
# 0.6666666666666666

# %%
#8
a = 3
b = 5
  
c = a + b
  

print(c)

a += b
  

print(a)

a -= b

print(a)

a *= b
  

print(a)

a /= b

print(a)

a %= b

print(a)
a=9
b=2
a //= b
  

print(a)
a=9
b=2
a **= b
  

print(a)

a=9
b=2

a /= b
  
  
a = 3
b = 5
  

a ^= b
  

print(a)

print(a)


a=9
b=8
a >>= b
  

print(b)
a=9
b=2
a <<= b
  

print(b)
# Out:
# 8
# 8
# 3
# 15
# 3.0
# 3.0
# 4
# 81
# 6
# 6
# 8
# 2

# %%
#9
a=9
b=8
print(a==b)
print(a!=b)
print(a>=b)
print(a<=b)
# Out:
# False
# True
# True
# False

# %%
#10
a="true"
b="false"
print("x and y is:",a and b)
print("x or y is:",a or b)
print("x not y is:", not b)
# Out:
# x and y is: false
# x or y is: true
# x not y is: False

# %%
#11
a=10
b=15
print(a&b)#and
print(a|b)#or
print(-a)#not
print(a^b)#xor
print(a>>3)#right shift
# Out:
# 10
# 15
# -10
# 5
# 1

# %%
#12
x="silence silence"
print("s"in x)
print("q"in x)
# Out:
# True
# False

# %%
#13
x=5
y=10
a="hello"
b="world"
c=[1,2,3]
d=[1,2,3]
print(x is not y)

print(c is not d)

print(c is  d)
# Out:
# True
# True
# False

# %%
#14
a=['apple','banana','orange','cherry','mango','custard apple']
print(a[0])#using index
print(a[5])
print(a[-1])
print(a[-2])
print(a[2:5])#from 2 nd index
print(a[-1:-5])
print(a[-5:-2])
print(a[:4])
print(a[0:4])
# Out:
# apple
# custard apple
# custard apple
# mango
# ['orange', 'cherry', 'mango']
# []
# ['banana', 'orange', 'cherry']
# ['apple', 'banana', 'orange', 'cherry']
# ['apple', 'banana', 'orange', 'cherry']

# %%
#15
print("A series of character designated as one object known as a string"[::-1][4::3])
print("-----------")
print("welcome to python training program"[3:10][::-1])
# Out:
# taawkcbe  tgerca  is
# -----------
# ot emoc

# %%
16
p_phrase="was it a car or a cat i saw"
print(p_phrase.upper())
# Out:
# WAS IT A CAR OR A CAT I SAW

# %%
#17
x=int(input(""))
y=2*x
print(x*'z'+y*'o')
# Out:
# 5
# zzzzzoooooooooo
